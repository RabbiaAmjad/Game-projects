# %%
#Python project inpired by the 12 dancing pricesses💃🩰🪭

# %%
# Player stats
player={
    "magic": 50,
    "confidence":50,
    "energy":50,
}

# Welcome secreen
print("🌸✨ WELCOME TO THE ENCHANTED TILES ✨🌸")
print("A magical world inspired by 12 dancing princesses 💃")
print("Unlock all 12 tiles to reach the Lower World 🌙")
print("\nYour starting stats:")
print(player)


# -------------------------------------------🌷 Tulip Tile🌷-------------------------------------------------------

# Theme: Curiosity
# Task: Choose the correct dance step

def tulip_tile(player):
    print("\n🌷 TULIP TILE — THE DANCE OF CURIOSITY 🌷")
    print("A glowing tulip appears beneath your feet...")
    print("You must choose the correct rhythm to move forward.\n")

    print("Choose your dance step:")
    print("1️⃣ Slow Waltz")
    print("2️⃣ Fast Spin")

    choice = input("Enter 1 or 2 in text: ")

    if choice ==2:
        print("\n✨ Beautiful move! The tulip glows brighter ✨")
        player['confidence'] +=10
        player["magic"] +=5
        print("TULIP TILE UNLOCKED 🌷!")
        return True
    
    else:
        print("\n❌ The rhythm fades. Try again later.")
        player["energy"] -=5
        return False

# call the tile
tulip_unlocked = tulip_tile(player)

print("\nUpdated Stats:")
print(player)
# Out:
# 🌸✨ WELCOME TO THE ENCHANTED TILES ✨🌸
# A magical world inspired by 12 dancing princesses 💃
# Unlock all 12 tiles to reach the Lower World 🌙
#
# Your starting stats:
# {'magic': 50, 'confidence': 50, 'energy': 50}
#
# 🌷 TULIP TILE — THE DANCE OF CURIOSITY 🌷
# A glowing tulip appears beneath your feet...
# You must choose the correct rhythm to move forward.
#
# Choose your dance step:
# 1️⃣ Slow Waltz
# 2️⃣ Fast Spin
#
# ❌ The rhythm fades. Try again later.
#
# Updated Stats:
# {'magic': 50, 'confidence': 50, 'energy': 45}

# %%
# -------------------------------------------🌷 Tulip Tile🌷-------------------------------------------------------

# Theme: Curiosity
# Task: Choose the correct dance step

def tulip_tile(player):
    print("\n🌷 TULIP TILE — THE DANCE OF CURIOSITY 🌷")
    print("A glowing tulip appears beneath your feet...")
    print("You must choose the correct rhythm to move forward.\n")

    print("Choose your dance step:")
    print("1️⃣ Slow Waltz")
    print("2️⃣ Fast Spin")

    choice = input("Enter 1 or 2 in text: ")

    if choice ==2:
        print("\n✨ Beautiful move! The tulip glows brighter ✨")
        player['confidence'] +=10
        player["magic"] +=5
        print("TULIP TILE UNLOCKED 🌷!")
        return True
    
    else:
        print("\n❌ The rhythm fades. Try again later.")
        player["energy"] -=5
        return False

# call the tile
tulip_unlocked = tulip_tile(player)

print("\nUpdated Stats:")
print(player)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 30
#      27         return False
#      29 # call the tile
# ---> 30 tulip_unlocked = tulip_tile(player)
#      32 print("\nUpdated Stats:")
#      33 print(player)
#
# NameError: name 'player' is not defined
